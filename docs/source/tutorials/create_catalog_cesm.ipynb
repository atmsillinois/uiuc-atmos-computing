# %% [markdown]
# # Create Catalog for CESM output

# %%
import pathlib
import os
from os import listdir
from os.path import isfile, join
import shutil

import intake
from ecgtools import Builder
from ecgtools.parsers.cesm import parse_cesm_timeseries

import pandas as pd 
import xarray as xr
import numpy as np
import itertools

# %% [markdown]
# ## Step 0: Move Files from `data_tmp` to `data` and Create New Folders if needed

# %%
# Path of new downloaded CESM data 
path='/data/keeling/a/cristi/a/data_tmp/'
# rootpath of target directory.
rootpath='/data/keeling/a/cristi/a/esm_data/cesm/CESM_LME'

def target_location_cmip(fname,rootpath): #generates target location 
    if rootpath[-1]!='/':
        rootpath=rootpath+'/'
    fname_set=fname.split('_')     
    location=rootpath+fname_set[2]+'/'+fname_set[3]+'/'+fname_set[4]+'/'# index need change based on CESM files are named
    return location

# move files from current folder to target folders
k_moved=0
for j in listdir(path): #read all downlaoded files in data_tmp
    current_dir=os.path.join(path, j) 
    target_dir= target_location_cmip(j,rootpath)
    if target_dir!=current_dir:
        if os.path.exists(target_dir)==False:
            os.makedirs(target_dir) #make directories 
        shutil.move(current_dir,target_dir) #move files 
        k_moved+=1
        
print('moved '+str(k_moved)+' files')

# %% [markdown]
# ## Step 1: Get updated list of Subdirectories

# %% [markdown]
# 1. Log onto Keeling and go to `/data/keeling/a/cristi/a/data/cesm`
#
# 2. Run the following line of code to the get the most updated list of all subdirectories
#
# `readlink -f $(find . -type d -path '*/*' -prune) > subdir_list.csv`

# %% [markdown]
# ## Get list of all subdirectories in `/data/keeling/a/cristi/a/data/cesm2`

# %%
filepathlist = pd.read_csv('/data/keeling/a/cristi/a/esm_data/cesm/subdir_list.csv',header=None,names=['dirpaths']).values.tolist()

# Transform list of lists to list of strings
filepath=list(itertools.chain.from_iterable(filepathlist))
filepath
# Out:
# ['/data/cristi/a/cristi/esm_data/cesm/CESM_LME']

# %% [markdown]
# ## Create Catalog Builder and Build the Catalog

# %%
# Create the Builder
cat_builder = Builder(
    # Directory of Organized CMIP6 files 
    paths=filepath)

# Build the Catalog
catalog = cat_builder.build(parsing_func=parse_cesm_timeseries)
# Out:
# /data/keeling/a/rytam2/miniconda3/lib/python3.9/site-packages/ecgtools/parsers/cesm.py:240: UserWarning: Using the default frequency definitions
#   warnings.warn('Using the default frequency definitions')
# /data/keeling/a/rytam2/miniconda3/lib/python3.9/site-packages/ecgtools/builder.py:202: UserWarning: Unable to parse 1 assets. A list of these assets can be found in `.invalid_assets` attribute.
#   self.get_assets().parse(

# %% [markdown]
# # Check and Save the Catalog

# %%
# Browse the catalog
catalog.df
# Out:
#    component stream                              case member_id variable  \
# 1        ocn  pop.h  b.ie12.B1850C5CN.f19_g16.LME.002       002     R18O
# 2        ocn  pop.h  b.ie12.B1850C5CN.f19_g16.LME.002       002     R18O
# 3        ocn  pop.h  b.ie12.B1850C5CN.f19_g16.LME.002       002     R18O
# 4        ocn  pop.h  b.ie12.B1850C5CN.f19_g16.LME.002       002     R18O
# 5        ocn  pop.h  b.ie12.B1850C5CN.f19_g16.LME.002       002     R18O
# 6        ocn  pop.h  b.ie12.B1850C5CN.f19_g16.LME.002       002     R18O
# 7        ocn  pop.h  b.ie12.B1850C5CN.f19_g16.LME.002       002     R18O
# 8        ocn  pop.h  b.ie12.B1850C5CN.f19_g16.LME.002       002     R18O
# 9        ocn  pop.h  b.ie12.B1850C5CN.f19_g16.LME.002       002     R18O
# 10       ocn  pop.h  b.ie12.B1850C5CN.f19_g16.LME.002       002     R18O
# 11       ocn  pop.h  b.ie12.B1850C5CN.f19_g16.LME.002       002     R18O
# 12       ocn  pop.h  b.ie12.B1850C5CN.f19_g16.LME.002       002     R18O
# 13       ocn  pop.h  b.ie12.B1850C5CN.f19_g16.LME.002       002     R18O
# 14       ocn  pop.h  b.ie12.B1850C5CN.f19_g16.LME.002       002     SALT
# 15       ocn  pop.h  b.ie12.B1850C5CN.f19_g16.LME.002       002     SALT
# 16       ocn  pop.h  b.ie12.B1850C5CN.f19_g16.LME.002       002     SALT
# 17       ocn  pop.h  b.ie12.B1850C5CN.f19_g16.LME.002       002     SALT
# 18       ocn  pop.h  b.ie12.B1850C5CN.f19_g16.LME.002       002     SALT
# 19       ocn  pop.h  b.ie12.B1850C5CN.f19_g16.LME.002       002     SALT
# 20       ocn  pop.h  b.ie12.B1850C5CN.f19_g16.LME.002       002     SALT
# 21       ocn  pop.h  b.ie12.B1850C5CN.f19_g16.LME.002       002     SALT
# 22       ocn  pop.h  b.ie12.B1850C5CN.f19_g16.LME.002       002     SALT
# 23       ocn  pop.h  b.ie12.B1850C5CN.f19_g16.LME.002       002     SALT
# 24       ocn  pop.h  b.ie12.B1850C5CN.f19_g16.LME.002       002     SALT
# 25       ocn  pop.h  b.ie12.B1850C5CN.f19_g16.LME.002       002     SALT
# 26       ocn  pop.h  b.ie12.B1850C5CN.f19_g16.LME.002       002     SALT
#
#    start_time end_time     time_range long_name          units  \
# 1     0850-01  0899-12  085001-089912      R18O       unitless
# 2     0900-01  0999-12  090001-099912      R18O       unitless
# 3     1000-01  1099-12  100001-109912      R18O       unitless
# 4     1100-01  1199-12  110001-119912      R18O       unitless
# 5     1200-01  1299-12  120001-129912      R18O       unitless
# 6     1300-01  1399-12  130001-139912      R18O       unitless
# 7     1400-01  1499-12  140001-149912      R18O       unitless
# 8     1500-01  1599-12  150001-159912      R18O       unitless
# 9     1600-01  1699-12  160001-169912      R18O       unitless
# 10    1700-01  1799-12  170001-179912      R18O       unitless
# 11    1800-01  1849-12  180001-184912      R18O       unitless
# 12    1800-01  1899-12  180001-189912      R18O       unitless
# 13    1850-01  2005-12  185001-200512      R18O       unitless
# 14    0850-01  0899-12  085001-089912  Salinity  gram/kilogram
# 15    0900-01  0999-12  090001-099912  Salinity  gram/kilogram
# 16    1000-01  1099-12  100001-109912  Salinity  gram/kilogram
# 17    1100-01  1199-12  110001-119912  Salinity  gram/kilogram
# 18    1200-01  1299-12  120001-129912  Salinity  gram/kilogram
# 19    1300-01  1399-12  130001-139912  Salinity  gram/kilogram
# 20    1400-01  1499-12  140001-149912  Salinity  gram/kilogram
# 21    1500-01  1599-12  150001-159912  Salinity  gram/kilogram
# 22    1600-01  1699-12  160001-169912  Salinity  gram/kilogram
# 23    1700-01  1799-12  170001-179912  Salinity  gram/kilogram
# 24    1800-01  1849-12  180001-184912  Salinity  gram/kilogram
# 25    1800-01  1899-12  180001-189912  Salinity  gram/kilogram
# 26    1850-01  2005-12  185001-200512  Salinity  gram/kilogram
#
#     vertical_levels frequency  \
# 1               1.0   month_1
# 2               1.0   month_1
# 3               1.0   month_1
# 4               1.0   month_1
# 5               1.0   month_1
# 6               1.0   month_1
# 7               1.0   month_1
# 8               1.0   month_1
# 9               1.0   month_1
# 10              1.0   month_1
# 11              1.0   month_1
# 12              1.0   month_1
# 13              1.0   month_1
# 14              1.0   month_1
# 15              1.0   month_1
# 16              1.0   month_1
# 17              1.0   month_1
# 18              1.0   month_1
# 19              1.0   month_1
# 20              1.0   month_1
# 21              1.0   month_1
# 22              1.0   month_1
# 23              1.0   month_1
# 24              1.0   month_1
# 25              1.0   month_1
# 26              1.0   month_1
#
#                                                  path
# 1   /data/cristi/a/cristi/data/CESM_LME/b.ie12.B18...
# 2   /data/cristi/a/cristi/data/CESM_LME/b.ie12.B18...
# 3   /data/cristi/a/cristi/data/CESM_LME/b.ie12.B18...
# 4   /data/cristi/a/cristi/data/CESM_LME/b.ie12.B18...
# 5   /data/cristi/a/cristi/data/CESM_LME/b.ie12.B18...
# 6   /data/cristi/a/cristi/data/CESM_LME/b.ie12.B18...
# 7   /data/cristi/a/cristi/data/CESM_LME/b.ie12.B18...
# 8   /data/cristi/a/cristi/data/CESM_LME/b.ie12.B18...
# 9   /data/cristi/a/cristi/data/CESM_LME/b.ie12.B18...
# 10  /data/cristi/a/cristi/data/CESM_LME/b.ie12.B18...
# 11  /data/cristi/a/cristi/data/CESM_LME/b.ie12.B18...
# 12  /data/cristi/a/cristi/data/CESM_LME/b.ie12.B18...
# 13  /data/cristi/a/cristi/data/CESM_LME/b.ie12.B18...
# 14  /data/cristi/a/cristi/data/CESM_LME/b.ie12.B18...
# 15  /data/cristi/a/cristi/data/CESM_LME/b.ie12.B18...
# 16  /data/cristi/a/cristi/data/CESM_LME/b.ie12.B18...
# 17  /data/cristi/a/cristi/data/CESM_LME/b.ie12.B18...
# 18  /data/cristi/a/cristi/data/CESM_LME/b.ie12.B18...
# 19  /data/cristi/a/cristi/data/CESM_LME/b.ie12.B18...
# 20  /data/cristi/a/cristi/data/CESM_LME/b.ie12.B18...
# 21  /data/cristi/a/cristi/data/CESM_LME/b.ie12.B18...
# 22  /data/cristi/a/cristi/data/CESM_LME/b.ie12.B18...
# 23  /data/cristi/a/cristi/data/CESM_LME/b.ie12.B18...
# 24  /data/cristi/a/cristi/data/CESM_LME/b.ie12.B18...
# 25  /data/cristi/a/cristi/data/CESM_LME/b.ie12.B18...
# 26  /data/cristi/a/cristi/data/CESM_LME/b.ie12.B18...

# %%
# Save the catalog as .csv 
catalog.df.to_csv('/data/keeling/a/cristi/a/data/cesm_lme_catalog.csv', index=False)
