# %% [markdown]
# # Create Catalog for CMIP6 output

# %%
# Load packages
import pathlib
import intake
from ecgtools import Builder
from ecgtools.parsers import parse_cmip6
import pandas as pd 
import xarray as xr
import numpy as np
import itertools
from os import listdir
from os.path import isfile, join
import shutil

# %% [markdown]
# ## Step 0: Move Files from `data_tmp` to `data` and Create New Folders if needed

# %%
# Path of new downloaded CMIP6 data 
path='/data/keeling/a/cristi/a/data_tmp/cmip6'
# rootpath of target directory.
rootpath='/data/keeling/a/cristi/a/esm_data/cmip6'

def target_location_cmip(fname,rootpath): #generates target location 
    if rootpath[-1]!='/':
        rootpath=rootpath+'/'
    fname_set=fname.split('_')     
    location=rootpath+fname_set[2]+'/'+fname_set[3]+'/'+fname_set[4]+'/'    
    return location

# move files from current folder to target folders
k_moved=0
for j in listdir(path): #read all downlaoded files in data_tmp
    current_dir=os.path.join(path, j) 
    target_dir= target_location_cmip(j,rootpath)
    if target_dir!=current_dir:
        if os.path.exists(target_dir)==False:
            os.makedirs(target_dir) #make directories 
        shutil.move(current_dir,target_dir) #move files 
        k_moved+=1
        
print('moved '+str(k_moved)+' files')
# Out:
# moved 0 files

# %% [markdown]
# ## Step 1: Get updated list of Subdirectories

# %% [markdown]
# 1. Log onto Keeling and go to `/data/keeling/a/cristi/a/esm_data/cmip6`
#
# 2. Run the following line of code to the get the most updated list of all subdirectories
#
# `readlink -f $(find . -type d -path '*/r*' -prune) > subdir_list.csv`

# %% [markdown]
# ## Step 2: Load list of all subdirectories from `/data/keeling/a/cristi/a/esm_data/cmip6` to Notebook

# %%
filepathlist = pd.read_csv('/data/keeling/a/cristi/a/esm_data/cmip6/subdir_list.csv',\
                       header=None,names=['dirpaths']).values.tolist()

# Transform list of lists to list of strings
filepath=list(itertools.chain.from_iterable(filepathlist))

# %% [markdown]
# ## Step 3: Create Catalog Builder and Build the Catalog

# %%
# Create the Builder
cat_builder = Builder(
    # Directory of Organized CMIP6 files 
    paths=filepath)

# Build the Catalog
catalog = cat_builder.build(parsing_func=parse_cmip6)
# Out:
# /data/keeling/a/rytam2/miniconda3/lib/python3.9/site-packages/xarray/conventions.py:523: SerializationWarning: variable 'rlut' has multiple fill values {1e+20, 1e+20}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /data/keeling/a/rytam2/miniconda3/lib/python3.9/site-packages/xarray/conventions.py:523: SerializationWarning: variable 'rlutcs' has multiple fill values {1e+20, 1e+20}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /data/keeling/a/rytam2/miniconda3/lib/python3.9/site-packages/xarray/conventions.py:523: SerializationWarning: variable 'rsdt' has multiple fill values {1e+20, 1e+20}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /data/keeling/a/rytam2/miniconda3/lib/python3.9/site-packages/xarray/conventions.py:523: SerializationWarning: variable 'rsut' has multiple fill values {1e+20, 1e+20}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /data/keeling/a/rytam2/miniconda3/lib/python3.9/site-packages/xarray/conventions.py:523: SerializationWarning: variable 'rsutcs' has multiple fill values {1e+20, 1e+20}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /data/keeling/a/rytam2/miniconda3/lib/python3.9/site-packages/xarray/conventions.py:523: SerializationWarning: variable 'tas' has multiple fill values {1e+20, 1e+20}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /data/keeling/a/rytam2/miniconda3/lib/python3.9/site-packages/xarray/conventions.py:523: SerializationWarning: variable 'pr' has multiple fill values {1e+20, 1e+20}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /data/keeling/a/rytam2/miniconda3/lib/python3.9/site-packages/xarray/conventions.py:523: SerializationWarning: variable 'ta' has multiple fill values {1e+20, 1e+20}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /data/keeling/a/rytam2/miniconda3/lib/python3.9/site-packages/ecgtools/builder.py:202: UserWarning: Unable to parse 38 assets. A list of these assets can be found in `.invalid_assets` attribute.
#   self.get_assets().parse(

# %% [markdown]
# ## Step 4: Check and Save the Catalog

# %%
# Browse the catalog
catalog.df
# Out:
#        activity_id branch_method branch_time_in_child branch_time_in_parent  \
# 0             CMIP      standard                  0.0                   0.0
# 1             CMIP      standard                  0.0                   0.0
# 2             CMIP      standard                  0.0                   0.0
# 3             CMIP      standard                  0.0                   0.0
# 4             CMIP      standard                  0.0                   0.0
# ...            ...           ...                  ...                   ...
# 11431  ScenarioMIP      standard              59400.0               59400.0
# 11432  ScenarioMIP      standard              59400.0               59400.0
# 11433  ScenarioMIP      standard              59400.0               59400.0
# 11434  ScenarioMIP      standard              59400.0               59400.0
# 11435  ScenarioMIP      standard              59400.0               59400.0
#
#                            experiment experiment_id frequency  \
# 0           abrupt quadrupling of CO2  abrupt-4xCO2       mon
# 1           abrupt quadrupling of CO2  abrupt-4xCO2       mon
# 2           abrupt quadrupling of CO2  abrupt-4xCO2       mon
# 3           abrupt quadrupling of CO2  abrupt-4xCO2       mon
# 4           abrupt quadrupling of CO2  abrupt-4xCO2       mon
# ...                               ...           ...       ...
# 11431  update of RCP8.5 based on SSP5        ssp585       mon
# 11432  update of RCP8.5 based on SSP5        ssp585       mon
# 11433  update of RCP8.5 based on SSP5        ssp585       mon
# 11434  update of RCP8.5 based on SSP5        ssp585       mon
# 11435  update of RCP8.5 based on SSP5        ssp585       mon
#
#                                                 grid grid_label  \
# 0       native atmosphere N96 grid (144x192 latxlon)         gn
# 1       native atmosphere N96 grid (144x192 latxlon)         gn
# 2       native atmosphere N96 grid (144x192 latxlon)         gn
# 3       native atmosphere N96 grid (144x192 latxlon)         gn
# 4       native atmosphere N96 grid (144x192 latxlon)         gn
# ...                                              ...        ...
# 11431  Native N96 grid; 192 x 144 longitude/latitude         gn
# 11432  Native N96 grid; 192 x 144 longitude/latitude         gn
# 11433  Native N96 grid; 192 x 144 longitude/latitude         gn
# 11434  Native N96 grid; 192 x 144 longitude/latitude         gn
# 11435  Native N96 grid; 192 x 144 longitude/latitude         gn
#
#       institution_id  ...                              standard_name  \
# 0       CSIRO-ARCCSS  ...            surface_upward_latent_heat_flux
# 1       CSIRO-ARCCSS  ...          surface_upward_sensible_heat_flux
# 2       CSIRO-ARCCSS  ...   surface_downwelling_longwave_flux_in_air
# 3       CSIRO-ARCCSS  ...     surface_upwelling_longwave_flux_in_air
# 4       CSIRO-ARCCSS  ...                 toa_outgoing_longwave_flux
# ...              ...  ...                                        ...
# 11431           MOHC  ...  surface_downwelling_shortwave_flux_in_air
# 11432           MOHC  ...                toa_incoming_shortwave_flux
# 11433           MOHC  ...    surface_upwelling_shortwave_flux_in_air
# 11434           MOHC  ...                toa_outgoing_shortwave_flux
# 11435           MOHC  ...                            air_temperature
#
#                                      long_name  units vertical_levels  \
# 0              Surface Upward Latent Heat Flux  W m-2             1.0
# 1            Surface Upward Sensible Heat Flux  W m-2             1.0
# 2       Surface Downwelling Longwave Radiation  W m-2             1.0
# 3         Surface Upwelling Longwave Radiation  W m-2             1.0
# 4              TOA Outgoing Longwave Radiation  W m-2             1.0
# ...                                        ...    ...             ...
# 11431  Surface Downwelling Shortwave Radiation  W m-2             1.0
# 11432         TOA Incident Shortwave Radiation  W m-2             1.0
# 11433    Surface Upwelling Shortwave Radiation  W m-2             1.0
# 11434         TOA Outgoing Shortwave Radiation  W m-2             1.0
# 11435             Near-Surface Air Temperature      K             1.0
#
#       init_year           start_time             end_time  \
# 0           NaN  0950-01-16 12:00:00  1099-12-16 12:00:00
# 1           NaN  0950-01-16 12:00:00  1099-12-16 12:00:00
# 2           NaN  0950-01-16 12:00:00  1099-12-16 12:00:00
# 3           NaN  0950-01-16 12:00:00  1099-12-16 12:00:00
# 4           NaN  0950-01-16 12:00:00  1099-12-16 12:00:00
# ...         ...                  ...                  ...
# 11431       NaN  2015-01-16 00:00:00  2100-12-16 00:00:00
# 11432       NaN  2015-01-16 00:00:00  2100-12-16 00:00:00
# 11433       NaN  2015-01-16 00:00:00  2100-12-16 00:00:00
# 11434       NaN  2015-01-16 00:00:00  2100-12-16 00:00:00
# 11435       NaN  2015-01-16 00:00:00  2100-12-16 00:00:00
#
#                                     time_range  \
# 0      0950-01-16 12:00:00-1099-12-16 12:00:00
# 1      0950-01-16 12:00:00-1099-12-16 12:00:00
# 2      0950-01-16 12:00:00-1099-12-16 12:00:00
# 3      0950-01-16 12:00:00-1099-12-16 12:00:00
# 4      0950-01-16 12:00:00-1099-12-16 12:00:00
# ...                                        ...
# 11431  2015-01-16 00:00:00-2100-12-16 00:00:00
# 11432  2015-01-16 00:00:00-2100-12-16 00:00:00
# 11433  2015-01-16 00:00:00-2100-12-16 00:00:00
# 11434  2015-01-16 00:00:00-2100-12-16 00:00:00
# 11435  2015-01-16 00:00:00-2100-12-16 00:00:00
#
#                                                     path version
# 0      /data/cristi/a/cristi/data/cmip6/ACCESS-CM2/ab...      v0
# 1      /data/cristi/a/cristi/data/cmip6/ACCESS-CM2/ab...      v0
# 2      /data/cristi/a/cristi/data/cmip6/ACCESS-CM2/ab...      v0
# 3      /data/cristi/a/cristi/data/cmip6/ACCESS-CM2/ab...      v0
# 4      /data/cristi/a/cristi/data/cmip6/ACCESS-CM2/ab...      v0
# ...                                                  ...     ...
# 11431  /data/cristi/a/cristi/data/cmip6/UKESM1-0-LL/s...      v0
# 11432  /data/cristi/a/cristi/data/cmip6/UKESM1-0-LL/s...      v0
# 11433  /data/cristi/a/cristi/data/cmip6/UKESM1-0-LL/s...      v0
# 11434  /data/cristi/a/cristi/data/cmip6/UKESM1-0-LL/s...      v0
# 11435  /data/cristi/a/cristi/data/cmip6/UKESM1-0-LL/s...      v0
#
# [11398 rows x 36 columns]

# %%
# Save the catalog as .csv 
catalog.df.to_csv('/data/keeling/a/cristi/a/esm_data/cmip6_catalog.csv', index=False)
